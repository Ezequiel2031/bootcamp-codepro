# %%
nombre = ("Ezequiel")
edad = 18
ciudad = ("San Lorenzo.")
print(nombre, edad, ciudad)
# Out:
# Ezequiel 18 San Lorenzo.

# %%
cantidad_de_manzanas = 20
cantidad_de_naranjas = 17
cantidad_de_frutas = (cantidad_de_manzanas + cantidad_de_naranjas)
print(cantidad_de_frutas)
# Out:
# 37

# %%
frutas_vendidas = 14
cantidad_de_frutas = 37
frutas_restantes = (cantidad_de_frutas - frutas_vendidas)
print(frutas_restantes)
# Out:
# 23

# %%
nombre = "Juan"
apellido = "Guzman"
print(nombre + " "+apellido, "Mucho gusto")
# Out:
# Juan Guzman Mucho gusto

# %%
cantidad_de_niños = int(input ("Ingrese la cantidad de niños"))
cantidad_de_caramelos = int(input("Ingrese la cantidad de caramelos"))
# Out:
# 0

# %%
def mixto():
    pan = input('Cuantos panes')
    jamon = input('Cuanto jamon')
    queso = input('Cuanto queso')
    print(f"Aqui tienes tu mixto con, {pan} panes, {jamon} jamon, {queso} queso.1")
mixto()
# Out:
# Aqui tienes tu mixto con, 2 panes 1 jamon 1 queso
# Aqui tienes tu mixto con,  panes  jamon  queso
# Aqui tienes tu mixto con,  panes  jamon  queso

# %%
pedido = input('Ingrese su pedido')
bebida = input('Ingrese en nombre de la bebida')
def pedidos(pedido, bebida):
    print(f'Preparando tu pedido de: {pedido} con {bebida}' )
    print('Tu pedido esta listo')

pedidos(pedido, bebida)
# Out:
# Preparando tu pedido de: Sushi Sprite
# Tu pedido esta listo

# %%
precio = input('Precio del producto')
