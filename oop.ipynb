# %%
class Animal:
   animal1 = "gato"
   def __init__(self, nombre, color):
      self.nombre = nombre
      self.color = color
   def presentarse (self):
      print(f"Hola me llamo, {self.nombre} y soy un {Animal.animal1}, de color {self.color}.")
   
   def hablar (self):
      print("Cuando hablo digo Miau")

animal1 = Animal ("Michi", "Gris")

animal1.presentarse()
animal1.hablar()
# Out:
# Hola me llamo, Michi y soy un gato, de color Gris.
# Cuando hablo digo Miau

# %%
class Madre:
    madre1 = "Madre"
    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad
class Hija1(Madre):
    pass
class Hija2(Madre):
    pass
Hija1 = Madre("Luna", "15")
Hija2 = Madre("Sol", "18")

print(Hija1.nombre, Hija1.edad)
print(Hija2.nombre, Hija2.edad)
# Out:
# Luna 15
# Sol 18

# %%
class Superheroe:
    superheroe1 = "Pepito"
    def __init__(self, nombre, poderes):
        self.nombre = nombre
        self.poderes = poderes
