# %%
mi_contacto = {}

mi_contacto = input("Ingrese su numero de telefono: ")
print("Su contacto es: " + mi_contacto)
mi_nombre = input("Ingrese su nombre: ")
print("Su nombre es: " + mi_nombre)
mi_edad = input("Ingrese su edad: ")
print("Su edad es: " + mi_edad)
mi_correo = input("Ingrese su correo electrónico: ")
print("Su correo electrónico es: " + mi_correo)
# Out:
# Su contacto es: 0998764342
# Su nombre es: Fede
# Su edad es: 89
# Su correo electrónico es: esfsef@ffvxd

# %%
contacto = {}
print(contacto)
mi_nombre["nombre"] = input("Ingrese su nombre: ")
print(contacto)
contacto["apellido"]= input("Ingrese su apellido")
print(contacto)
mi_edad["edad"]= input('Ingrese su edad')
print(contacto)
contacto["Correo"]= input('Ingrese su correo')
print(contacto)
# Out:
# {'nombre': 'Eze'}
# {'nombre': 'Eze', 'apellido': 'messironaldo'}

# %%
tarjeta_personal={}

def crear():
    clave=input("Ingrese el nombre de la clave")
    valor=input("Ingrese un valor para la clave")
    tarjeta_personal[clave]=valor


def modificar():
    clave=input("Ingrese el nombre de la clave a modificar")
    valor=input("Ingrese un nuevo valor")
    tarjeta_personal[clave]=valor

def eliminar():
    clave= input("Ingrese el nombre de la clave que desea eliminar")
    del tarjeta_personal[clave]


while True:
    opcion=int(input("Ingrese una opcion: 1. Crear, 2. Modificar, 3. Eliminar, 4. Salir"))
    if opcion == 1:
        crear()
        print(tarjeta_personal)
    elif opcion ==2:
        modificar()
        print(tarjeta_personal)
    elif opcion==3:
        eliminar()
        print(tarjeta_personal)
    else :
        break
# Out:
# {'21': 'ezequiel'}

# %%
tarjeta_personal={}

def crear():
    clave=input("Ingrese el nombre de la clave")
    valor=input("Ingrese un valor para la clave")
    tarjeta_personal[clave]=valor


def modificar():
    clave=input("Ingrese el nombre de la clave a modificar")
    valor=input("Ingrese un nuevo valor")
    tarjeta_personal[clave]=valor

def mostrar():
    print(tarjeta_personal)

while True:
    opcion=int(input("Ingrese una opcion: 1. Crear, 2. Modificar, 3. Mostrar, 4. Salir"))
    if opcion == 1:
        crear()
        print(tarjeta_personal)
    elif opcion ==2:
        modificar()
        print(tarjeta_personal)
    elif opcion==3:
        mostrar()
        print(tarjeta_personal)
    else :
        break
# Out:
# {}
# {}
# {'21': 'ezequiel'}
# {'21': 'ezequiel'}
# {'21': 'ezequiel'}
